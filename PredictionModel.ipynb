# %%
import matplotlib.pyplot as plt
import numpy as np

from modules import *

# %% [markdown]
# ## Read Data

# %%
accidents = pd.read_csv("monatszahlen2405_verkehrsunfaelle_export_31_05_24_r.csv")

# %% [markdown]
# ## Preprocessing
# 1. Keep only first 5 columns (they are the important ones)
# 2. Split the dataset into values before 2020 and after 2020
# 2. Replace NULL values with 0
# 3. Remove the "Summe" values from column "MONAT"
# 4. Convert values of the column "MONAT" from String to DateTime

# %%
accidents_until_2020, accidents_after_2020, accidents_until_2020_by_year, accidents_after_2020_by_year= preproc(accidents)

# %% [markdown]
# ## Visualization

# %%
plot_total_accidents(accidents_until_2020, save=False)

# %%
plot_accidents_over_time(accidents_until_2020_by_year, type="insgesamt", save=False)

# %% [markdown]
# ## Building a model
